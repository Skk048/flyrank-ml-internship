# %% [markdown]
# <a href="https://colab.research.google.com/github/Skk048/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Skk048/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# Lane: Content Refresh / Declining Pages
# I want to investigate which observable page signals are associated with declining search performance. The goal is to identify pages that may need content updates so that the team can prioritize which pages to review first.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Decision: Which pages should be prioritized for review or content refresh?
# Action: A content or SEO team can review the highest-priority pages and decide whether they need updating.
# Cost of a wrong call: Prioritizing the wrong pages wastes time, while missing genuinely declining pages may delay useful updates.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/flyrank-bih/flyrank-ml-internship-starter/main/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(url)

print("Rows:", len(df))
print("Columns:", len(df.columns))

print("\nUseful numbers:")
print("Average impressions (90d):", round(df["impressions_90d"].mean(), 2))
print("Average CTR:", round(df["ctr"].mean(), 4))
print("Average position:", round(df["avg_position"].mean(), 2))
# Out:
# Rows: 30000
# Columns: 44
#
# Useful numbers:
# Average impressions (90d): 5200.37
# Average CTR: 0.5107
# Average position: 16.34

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# I can describe observed and directional relationships in the starter data and use them to support prioritization decisions. I cannot claim that these relationships prove causation or predict Google's ranking algorithm. The analysis only shows patterns in the available data and should be validated on new data before making operational decisions.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
